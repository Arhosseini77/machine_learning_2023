# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Data for class 1
x1 = [-2.0, -1.0, -1.5, -1.5, -0.5, 0.5, 0.5, 1.5, 1.5, 1.0]
y1 = [-1.0, -1.0, 0, 1, 0.5, 0.5, -0.5, -0.5, 0.5, -1]

# Data for class 2
x2 = [0, 1.5, 1, 2, 1, 1.5, 2.5, 1, 2]
y2 = [0.5, 0, 1, 1, 2, 2, 2, 3, 3]

# Create scatter plot
plt.scatter(x1, y1, c='black')
plt.scatter(x2, y2, c='red')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter plot of two classes')

plt.show()

# %%
####### p1 = p2 = 0.5 
# Data for class 1
x1 = [-2.0, -1.0, -1.5, -1.5, -0.5, 0.5, 0.5, 1.5, 1.5, 1.0]
y1 = [-1.0, -1.0, 0, 1, 0.5, 0.5, -0.5, -0.5, 0.5, -1]
# Data for class 2
x2 = [0, 1.5, 1, 2, 1, 1.5, 2.5, 1, 2]
y2 = [0.5, 0, 1, 1, 2, 2, 2, 3, 3]

# Define function for decision boundary
def boundary(x, y):
    return 0.83*x**2 - 0.538*x*y - 2.42*x - 0.425*y**2 - 1.37*y + 2.152

plt.scatter(x1, y1, c='black')
plt.scatter(x2, y2, c='red')
x_range = np.arange(-2.5, 2.6, 0.1)
y_range = np.arange(-1.5, 3.6, 0.1)
# Create meshgrid
xx, yy = np.meshgrid(x_range, y_range)
# Evaluate decision boundary function at all points in meshgrid
zz = boundary(xx, yy)
# Plot decision boundary as contour plot
plt.contour(xx, yy, zz, levels=[0], colors='blue')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter plot with decision boundary(Assuming equal prior probability)')
plt.show()

# %%
####### minimum risk
# Data for class 1
x1 = [-2.0, -1.0, -1.5, -1.5, -0.5, 0.5, 0.5, 1.5, 1.5, 1.0]
y1 = [-1.0, -1.0, 0, 1, 0.5, 0.5, -0.5, -0.5, 0.5, -1]
# Data for class 2
x2 = [0, 1.5, 1, 2, 1, 1.5, 2.5, 1, 2]
y2 = [0.5, 0, 1, 1, 2, 2, 2, 3, 3]

# Define function for decision boundary
def boundary(x, y):
    return 0.83*x**2 - 0.538*x*y - 2.42*x - 0.425*y**2 - 1.37*y + 1.468

plt.scatter(x1, y1, c='black')
plt.scatter(x2, y2, c='red')
x_range = np.arange(-2.5, 2.6, 0.1)
y_range = np.arange(-1.5, 3.6, 0.1)
# Create meshgrid
xx, yy = np.meshgrid(x_range, y_range)
# Evaluate decision boundary function at all points in meshgrid
zz = boundary(xx, yy)
# Plot decision boundary as contour plot
plt.contour(xx, yy, zz, levels=[0], colors='blue')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter plot with decision boundary(minimum risk)')
plt.show()

# %%
####### p1 = 1/3 , p2 = 2/3
# Data for class 1
x1 = [-2.0, -1.0, -1.5, -1.5, -0.5, 0.5, 0.5, 1.5, 1.5, 1.0]
y1 = [-1.0, -1.0, 0, 1, 0.5, 0.5, -0.5, -0.5, 0.5, -1]
# Data for class 2
x2 = [0, 1.5, 1, 2, 1, 1.5, 2.5, 1, 2]
y2 = [0.5, 0, 1, 1, 2, 2, 2, 3, 3]

# Define function for decision boundary
def boundary(x, y):
    return 0.83*x**2 - 0.538*x*y - 2.42*x - 0.425*y**2 - 1.37*y + 1.468

plt.scatter(x1, y1, c='black')
plt.scatter(x2, y2, c='red')
x_range = np.arange(-2.5, 2.6, 0.1)
y_range = np.arange(-1.5, 3.6, 0.1)
# Create meshgrid
xx, yy = np.meshgrid(x_range, y_range)
# Evaluate decision boundary function at all points in meshgrid
zz = boundary(xx, yy)
# Plot decision boundary as contour plot
plt.contour(xx, yy, zz, levels=[0], colors='blue')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter plot with decision boundary(p1 = 1/3 , p = 2/3)')
plt.show()
